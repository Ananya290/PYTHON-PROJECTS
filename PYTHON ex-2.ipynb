# %%
Questions=[
    [" What is the largest animal in the world?", 'elephant', 'giraffe', 'blue whale', 'brown bear',3],
    
    ["What is the name of the world’s highest mountain?" ,  'Alps', 'Zugspitze', 'Annapurna', 'Mount Everest',4],
    
    ["How many wings does a butterfly have?",  '4', '2', '6', '5',1],
    
    ["At what age do teenagers become an adult in the UK?", '16', '18' , '20', '21',2],
    
    ["What is the capital city of Scotland?", 'Glasgow', 'London', 'Europe', 'Edinburgh',4],
    
    ["How many players are there in a football team?", '9', '10', '11', '12',3],
    
    [" What is the largest animal in the world?", 'elephant', 'giraffe', 'blue whale', 'brown bear',3],
    
    ["What is the name of the world’s highest mountain?" ,  'Alps', 'Zugspitze', 'Annapurna', 'Mount Everest',4],
    
    ["How many wings does a butterfly have?",  '4', '2', '6', '5',1],
    
    ["At what age do teenagers become an adult in the UK?", '16', '18' , '20', '21',2],
    
    ["What is the capital city of Scotland?", 'Glasgow', 'London', 'Europe', 'Edinburgh',4],
    
    ["How many players are there in a football team?", '9', '10', '11', '12',3],
]

# %%
levels=[1000,5000,10000,15000,20000,25000,50000,100000,150000,200000,500000,10000000]
money =0

# %%
for i in range(0,len(Questions)):
    question=Questions[i]
    print(question[0] , end =" ")
    print(f"Question for Rs. {levels[i]}")
    print(f"a. {question[1]}              b. {question[2]}")  
    print(f"c. {question[3]}              d. {question[4]} ")
    reply=int(input("enter your answer(1-4):"))
    if(reply==question[-1]):
        print(f"correct answer,you have won Rs. {levels[i]}")
        if(i==4):
            money=20000
        elif(i==8):
            money=100000
        elif(i==11):
             money=10000000
    else:
        print("Wrong Answer")
        break
        
print(f"Your take home money is {money}")
# Out:
#  What is the largest animal in the world? Question for Rs. 1000
# a. elephant              b. giraffe
# c. blue whale              d. brown bear
# enter your answer(1-4):3
# correct answer,you have won Rs. 1000
# What is the name of the world’s highest mountain? Question for Rs. 5000
# a. Alps              b. Zugspitze
# c. Annapurna              d. Mount Everest
# enter your answer(1-4):4
# correct answer,you have won Rs. 5000
# How many wings does a butterfly have? Question for Rs. 10000
# a. 4              b. 2
# c. 6              d. 5
# enter your answer(1-4):1
# correct answer,you have won Rs. 10000
# At what age do teenagers become an adult in the UK? Question for Rs. 15000
# a. 16              b. 18
# c. 20              d. 21
# enter your answer(1-4):2
# correct answer,you have won Rs. 15000
# What is the capital city of Scotland? Question for Rs. 20000
# a. Glasgow              b. London
# c. Europe              d. Edinburgh
# enter your answer(1-4):4
# ...
